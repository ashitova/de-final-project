# %%
import pandas as pd
import numpy as np

# Create a sample dataframe
df = pd.DataFrame({
    'hit_datetime': pd.date_range(start='2026-06-01', periods=1000, freq='10min'),
    'watch_id': np.random.randint(1000000, 9999999, 1000),
    'visit_id': np.random.randint(100000, 999999, 1000),
    'visit_datetime': pd.date_range(start='2026-06-01', periods=1000, freq='1h'),
    'client_id': np.random.randint(10000, 99999, 1000),
    'referer': np.random.choice(['https://google.com', 'https://yandex.ru', 'https://vk.com', None], 1000),
    'start_url': np.random.choice(['https://example.com/', 'https://example.com/products', 'https://example.com/blog'], 1000),
    'url': np.random.choice(['https://example.com/page1', 'https://example.com/page2', 'https://example.com/page3'], 1000),
    'end_url': np.random.choice(['https://example.com/cart', 'https://example.com/checkout', 'https://example.com/thankyou'], 1000),
    'visit_duration': np.random.randint(10, 3600, 1000),
    'page_views': np.random.randint(1, 20, 1000),
    'page_goals': [np.random.choice([0, 1], 3, p=[0.8, 0.2]).tolist() for _ in range(1000)],
    'page_goals_time': [pd.date_range(start='2026-06-01', periods=3, freq='1D').tolist() for _ in range(1000)],
    'goals_id': [np.random.choice([1, 2, 3], 3, p=[0.6, 0.3, 0.1]).tolist() for _ in range(1000)],
    'goals_datetime': [pd.date_range(start='2026-06-01', periods=3, freq='1D').tolist() for _ in range(1000)],
    'visit_source': np.random.choice(['organic', 'ad', 'direct', 'referral'], 1000),
    'is_new_user': np.random.choice([0, 1], 1000),
    'utm_source': np.random.choice(['google', 'yandex', 'vk', 'dzen', 'tg'], 1000),
    'utm_medium': np.random.choice(['cpc', 'post', 'cpm', 'social'], 1000),
    'utm_campaign': np.random.choice(['search01', 'search02', 'network01', 'network02'], 1000),
    'utm_term': np.random.choice(['{term1}', '{term2}', '{term3}'], 1000)
})

print(df.dtypes)
print(df.tail())
# Out:
# hit_datetime       datetime64[ns]
# watch_id                    int64
# visit_id                    int64
# visit_datetime     datetime64[ns]
# client_id                   int64
# referer                    object
# start_url                  object
# url                        object
# end_url                    object
# visit_duration              int64
# page_views                  int64
# page_goals                 object
# page_goals_time            object
# goals_id                   object
# goals_datetime             object
# visit_source               object
# is_new_user                 int64
# utm_source                 object
# utm_medium                 object
# utm_campaign               object
# utm_term                   object
# dtype: object
#            hit_datetime  watch_id  visit_id      visit_datetime  client_id  \
# 995 2026-06-07 21:50:00   3646196    509172 2026-07-12 11:00:00      98268
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@localhost:5432/postgres')

df.to_sql("web_analytics", engine)
# Out:
# 1000
